# %%
import pandas as pd

# %%
approval_df = pd.read_excel(r"C:\Users\User\Desktop\Columbia\Fall 21\Capstone\clean_approval_data.xlsx")

# %%
product_df = pd.read_excel(r"C:\Users\User\Desktop\Columbia\Fall 21\Capstone\ndcxls\product.xlsx")

# %%
approval_df.shape
# Out:
# (19256, 12)

# %%
approval_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Approval Date  \
# 0           0         19114    01/02/2001
# 1           1         19491    01/02/2002
# 2           2         19498    01/02/2002
# 3           3         19497    01/02/2002
# 4           4          5074    01/02/2003
#
#                                            Drug Name Submission  \
# 0                             VASOCON-ANDA   #018746   SUPPL-11
# 1  LIDOCAINE HYDROCHLORIDE IN PLASTIC CONTAINERAN...   SUPPL-11
# 2  LIDOCAINE HYDROCHLORIDE AND EPINEPHRINEANDA  #...    SUPPL-4
# 3  LIDOCAINE HYDROCHLORIDE AND EPINEPHRINEANDA  #...    SUPPL-4
# 4                        SULFINPYRAZONEANDA  #087665   SUPPL-22
#
#                                 Active Ingredients   Company  \
# 0  ANTAZOLINE PHOSPHATE; NAPHAZOLINE HYDROCHLORIDE  NOVARTIS
# 1                          LIDOCAINE HYDROCHLORIDE   HOSPIRA
# 2             EPINEPHRINE; LIDOCAINE HYDROCHLORIDE   HOSPIRA
# 3             EPINEPHRINE; LIDOCAINE HYDROCHLORIDE   HOSPIRA
# ...

# %%
product_df.head(5)
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0002-0800_662164fd-5ea0-4a08-bfd1-6b08bdd73342  0002-0800
# 1  0002-1200_480fceef-6596-4478-97de-677c155506b3  0002-1200
# 2  0002-1210_151a431b-f07b-4959-b6fa-c41ff80364c8  0002-1210
# 3  0002-1433_29acbbf5-e52a-43b3-9874-6a70d5a2a358  0002-1433
# 4  0002-1434_29acbbf5-e52a-43b3-9874-6a70d5a2a358  0002-1434
#
#            PRODUCTTYPENAME  PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0           HUMAN OTC DRUG  Sterile Diluent                   NaN
# 1  HUMAN PRESCRIPTION DRUG           Amyvid                   NaN
# 2  HUMAN PRESCRIPTION DRUG           TAUVID                   NaN
# 3  HUMAN PRESCRIPTION DRUG        Trulicity                   NaN
# 4  HUMAN PRESCRIPTION DRUG        Trulicity                   NaN
#
#   NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 0            diluent  INJECTION, SOLUTION  SUBCUTANEOUS            19870710
# ...

# %%
product_df['ID'] = product_df['APPLICATIONNUMBER']
product_df['ID'] = product_df['ID'].str.replace('NDA', '')
product_df['ID'] = product_df['ID'].str.replace('ANDA', '')
product_df['ID'] = product_df['ID'].str.replace('BLA', '')

# %%
product_df['ID'] = 'NDA' + product_df['ID'].astype(str)

# %%
approval_df.dtypes
# Out:
# Unnamed: 0                      int64
# Unnamed: 0.1                    int64
# Approval Date                  object
# Drug Name                      object
# Submission                     object
# Active Ingredients             object
# Company                        object
# Submission Classification *    object
# Submission Status              object
# year                            int64
# month                           int64
# ID                             object
# dtype: object

# %%
product_df.dtypes
# Out:
# PRODUCTID                            object
# PRODUCTNDC                           object
# PRODUCTTYPENAME                      object
# PROPRIETARYNAME                      object
# PROPRIETARYNAMESUFFIX                object
# NONPROPRIETARYNAME                   object
# DOSAGEFORMNAME                       object
# ROUTENAME                            object
# STARTMARKETINGDATE                    int64
# ENDMARKETINGDATE                    float64
# MARKETINGCATEGORYNAME                object
# APPLICATIONNUMBER                    object
# LABELERNAME                          object
# SUBSTANCENAME                        object
# ACTIVE_NUMERATOR_STRENGTH            object
# ACTIVE_INGRED_UNIT                   object
# PHARM_CLASSES                        object
# DEASCHEDULE                          object
# NDC_EXCLUDE_FLAG                     object
# LISTING_RECORD_CERTIFIED_THROUGH    float64
# ID                                   object
# dtype: object

# %%
match = approval_df.merge(product_df , on = 'ID', how = 'inner', suffixes = ('app','prod'))

# %%
match
# Out:
#        Unnamed: 0  Unnamed: 0.1 Approval Date  \
# 0              89         83228    01/09/2017
# 1              89         83228    01/09/2017
# 2              89         83228    01/09/2017
# 3              89         83228    01/09/2017
# 4              89         83228    01/09/2017
# ...           ...           ...           ...
# 13001       19253         16645    12/31/2020
# 13002       19255         16651    12/31/2020
# 13003       19255         16651    12/31/2020
# 13004       19255         16651    12/31/2020
# 13005       19255         16651    12/31/2020
#
#                              Drug Name Submission   Active Ingredients  \
# 0      NITROUS OXIDE, USPNDA   #209989     ORIG-1        NITROUS OXIDE
# 1      NITROUS OXIDE, USPNDA   #209989     ORIG-1        NITROUS OXIDE
# 2      NITROUS OXIDE, USPNDA   #209989     ORIG-1        NITROUS OXIDE
# 3      NITROUS OXIDE, USPNDA   #209989     ORIG-1        NITROUS OXIDE
# ...
