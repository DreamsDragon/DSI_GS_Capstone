# %%
import numpy as np
import pandas as pd
import re
pd.set_option('display.max_columns', None)

# %%
faers = pd.read_csv('/Users/architmatta/Documents/Columbia/Fall 2021/Capstone/Data/FAERS_2012Q4_2021Q1.csv', low_memory = False)

# %%
print(faers.shape)
faers.head()
# Out:
# (40584418, 22)
#    primaryid   caseid  drug_seq role_cod    drugname  val_vbm           route  \
# 0   34483284  3448328         1       PS     SUSTIVA        1  TRANSPLACENTAL
# 1   34483284  3448328         2       SS  NEVIRAPINE        1  TRANSPLACENTAL
# 2   34483284  3448328         3       SS    VIRACEPT        1  TRANSPLACENTAL
# 3   34483284  3448328         4       SS    COMBIVIR        1  TRANSPLACENTAL
# 4   34483284  3448328         5       SS    RETROVIR        1  TRANSPLACENTAL
#
#   dose_vbm  cum_dose_chr cum_dose_unit dechal rechal lot_nbr exp_dt nda_num  \
# 0  UNK UNK           NaN           NaN    NaN      U     NaN    NaN  020972
# 1      NaN           NaN           NaN    NaN      U     NaN    NaN     NaN
# 2  UNK UNK           NaN           NaN    NaN      U     NaN    NaN     NaN
# 3  UNK UNK           NaN           NaN    NaN      U     NaN    NaN     NaN
# 4  UNK UNK           NaN           NaN    NaN      U     NaN    NaN     NaN
#
# ...

# %%
faers['time'] = faers['origin'].str[4:8].str.upper()

# %%
faers.head()
# Out:
#    primaryid   caseid  drug_seq role_cod    drugname  val_vbm           route  \
# 0   34483284  3448328         1       PS     SUSTIVA        1  TRANSPLACENTAL
# 1   34483284  3448328         2       SS  NEVIRAPINE        1  TRANSPLACENTAL
# 2   34483284  3448328         3       SS    VIRACEPT        1  TRANSPLACENTAL
# 3   34483284  3448328         4       SS    COMBIVIR        1  TRANSPLACENTAL
# 4   34483284  3448328         5       SS    RETROVIR        1  TRANSPLACENTAL
#
#   dose_vbm  cum_dose_chr cum_dose_unit dechal rechal lot_nbr exp_dt nda_num  \
# 0  UNK UNK           NaN           NaN    NaN      U     NaN    NaN  020972
# 1      NaN           NaN           NaN    NaN      U     NaN    NaN     NaN
# 2  UNK UNK           NaN           NaN    NaN      U     NaN    NaN     NaN
# 3  UNK UNK           NaN           NaN    NaN      U     NaN    NaN     NaN
# 4  UNK UNK           NaN           NaN    NaN      U     NaN    NaN     NaN
#
# ...

# %%
faers['drugnameclean'] = faers['drugname'].str.upper().str.strip().str.replace('\W', '')
# Out:
# /Users/architmatta/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
faers.groupby(['drugnameclean', 'time']).size()
# Out:
# drugnameclean          time
#                        12Q4    10
#                        13Q1     3
#                        15Q2     1
#                        15Q3     1
#                        16Q4     1
#                                ..
# _RIBAVIRINTAB200MG     16Q4     1
# _TEMOZOLOMIDECAP100MG  20Q1     4
#                        20Q2     1
#                        20Q3     1
# _VITAMINC              20Q4     1
# Length: 1386138, dtype: int64

# %%
faers_summary = faers.groupby(['drugnameclean']).agg({'time': [min,max], 'primaryid': 'count'})

# %%
faers_summary.reset_index()
# Out:
#                                    time       primaryid
#                                     min   max     count
# drugnameclean
#                                    12Q4  20Q2        22
# 00002703                           20Q1  20Q1         1
# 00011902                           19Q3  21Q1         5
# 00082702001METFORMINHYDROCHLORIDE  20Q3  20Q3         1
# 001ESTRADIOLVAGINALCREAMUSP        20Q1  20Q1         1
# ...                                 ...   ...       ...
# _MYCOPHENOLATMOFCAP250MG           16Q4  19Q3         6
# _RIBAVIRINCAP200MG                 17Q4  19Q4         4
# _RIBAVIRINTAB200MG                 16Q4  16Q4         1
# _TEMOZOLOMIDECAP100MG              20Q1  20Q3         6
# _VITAMINC                          20Q4  20Q4         1
#
# [406571 rows x 3 columns]

# %%
faers_summary.reset_index().to_csv('/Users/architmatta/Documents/Columbia/Fall 2021/Capstone/Data/FAERS_Summary.csv')
